# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib



np.set_printoptions(threshold=np.inf)

# %%
fig = plt.figure(figsize=(10,4))
ax = fig.add_axes([0,0,1,1])
labels = ["Global Average","Random Assignment","First Attempt","Our Best Score"]
means = [1.11415, 1.89394, 1.03424, 0.93463]
ax.bar(labels, means)
plt.title("RMSE of several initial models")
plt.xlabel("Prediction Methods")
plt.ylabel("Root Mean Square Error (RMSE)")
plt.show()

# %%
fig = plt.figure(figsize=(10,4))
ax = fig.add_axes([0,0,1,1])
labels = ["5","10","15","20", "25", "30", "35", "40", "45", "50"]
means = [1.09043, 1.00417, 0.98032, 0.96393, 0.95831, 0.95268, 0.94852, 0.94598, 0.94235, 0.94256]
ax.scatter(labels, means)
ax.grid()
plt.title("RMSE latent factor prediction with varying number of factors")
plt.xlabel("Number of Factors")
plt.ylabel("Root Mean Square Error (RMSE)")
plt.show()
